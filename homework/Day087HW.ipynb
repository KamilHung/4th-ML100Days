# %% [markdown]
# ## Work
# 1. 請改變 reduce_lr 的 patience 和 factor 並比較不同設定下，對訓練/驗證集的影響
# 2. 請將 optimizer 換成 Adam、RMSprop 搭配 reduce_lr 並比較訓練結果

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.regularizers import l1_l2
from keras.layers import Input, Dense, BatchNormalization, Dropout
from keras.models import Model

def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128], l1_l2_ratio=1e-8, drp_ratio=0.2):
    """Code Here
    建立你的神經網路
    """
    input_layer = Input(input_shape)
    x = BatchNormalization()(input_layer)
    
    for i, n_units in enumerate(num_neurons):
        x = Dense(units=n_units, 
                               activation="relu", 
                               name="hidden_layer"+str(i+1),
                               kernel_regularizer=l1_l2(l1_l2_ratio))(x)
        x = BatchNormalization()(x)
        x = Dropout(drp_ratio)(x)
    
    out = Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = Model(inputs=[input_layer], outputs=[out])
    return model

# %%
LEARNING_RATE = 1e-3
EPOCHS = 25 # IF you feel too run to finish, try to make it smaller
BATCH_SIZE = 1024

# %%
# 載入 Callbacks
from keras.callbacks import ReduceLROnPlateau

optimizer_set = [keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=0.95),
                 keras.optimizers.Adam(lr=LEARNING_RATE),
                 keras.optimizers.RMSprop(lr=LEARNING_RATE)]

"""Code Here
建立實驗的比較組合
"""
reduce_lr_factor = [0.1, 0.5, 0.9]
redice_lr_patient = [1, 5, 9]

# %%
import itertools
results = {}
for i, (optim, reduce_factor, reduce_patient) in enumerate(itertools.product(optimizer_set, reduce_lr_factor, redice_lr_patient)):
    print("Numbers of exp: %i, reduce_factor: %.2f, reduce_patient: %i" % (i, reduce_factor, reduce_patient))
    model = build_mlp(input_shape=x_train.shape[1:])
    model.summary()
    model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optim)
    
    """Code Here
    設定 reduce learning rate 的 callback function
    """
    reduce_lr = ReduceLROnPlateau(factor=reduce_factor, 
                              min_lr=1e-12, 
                              monitor='val_loss', 
                              patience=reduce_patient, 
                              verbose=1)
    
    model.fit(x_train, y_train, 
              epochs=EPOCHS, 
              batch_size=BATCH_SIZE, 
              validation_data=(x_test, y_test), 
              shuffle=True,
              callbacks=[reduce_lr]
             )

    # Collect results
    exp_name_tag = ("exp-%s" % (i))
    results[exp_name_tag] = {'train-loss': model.history.history["loss"],
                             'valid-loss': model.history.history["val_loss"],
                             'train-acc': model.history.history["accuracy"],
                             'valid-acc': model.history.history["val_accuracy"]}
# Out:
#  - accuracy: 0.3193 - val_loss: 14.9485 - val_accuracy: 0.3691
# Epoch 9/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 15.1206 - accuracy: 0.3259 - val_loss: 14.8155 - val_accuracy: 0.3811
# Epoch 10/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.9985 - accuracy: 0.3327 - val_loss: 14.6895 - val_accuracy: 0.3869
# Epoch 11/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.8597 - accuracy: 0.3420 - val_loss: 14.5683 - val_accuracy: 0.3931
# Epoch 12/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.7367 - accuracy: 0.3464 - val_loss: 14.4457 - val_accuracy: 0.4021
# Epoch 13/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.6115 - accuracy: 0.3507 - val_loss: 14.3289 - val_accuracy: 0.4057
# Epoch 14/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.4877 - accuracy: 0.3561 - val_loss: 14.2118 - val_accuracy: 0.4120
# Epoch 15/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.3558 - accuracy: 0.3631 - val_loss: 14.0965 - val_accuracy: 0.4156
# Epoch 16/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.2502 - accuracy: 0.3649 - val_loss: 13.9816 - val_accuracy: 0.4203
# Epoch 17/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 14.1259 - accuracy: 0.3727 - val_loss: 13.8695 - val_accuracy: 0.4239
# Epoch 18/25
# 50000/50000 [==============================] - 1s 24us/step - loss: 14.0125 - accuracy: 0.3759 - val_loss: 13.7564 - val_accuracy: 0.4286
# Epoch 19/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 13.8886 - accuracy: 0.3790 - val_loss: 13.6437 - val_accuracy: 0.4318
# Epoch 20/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.7764 - accuracy: 0.3837 - val_loss: 13.5325 - val_accuracy: 0.4336
# Epoch 21/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 13.6586 - accuracy: 0.3883 - val_loss: 13.4226 - val_accuracy: 0.4357
# Epoch 22/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.5514 - accuracy: 0.3902 - val_loss: 13.3141 - val_accuracy: 0.4387
# Epoch 23/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.4442 - accuracy: 0.3908 - val_loss: 13.2064 - val_accuracy: 0.4418
# Epoch 24/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.3305 - accuracy: 0.3955 - val_loss: 13.1008 - val_accuracy: 0.4451
# Epoch 25/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 13.2293 - accuracy: 0.3955 - val_loss: 12.9956 - val_accuracy: 0.4483
# Numbers of exp: 24, reduce_factor: 0.90, reduce_patient: 1
# Model: "model_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_25 (InputLayer)        (None, 3072)              0
# _________________________________________________________________
# batch_normalization_97 (Batc (None, 3072)              12288
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_98 (Batc (None, 512)               2048
# _________________________________________________________________
# dropout_73 (Dropout)         (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_99 (Batc (None, 256)               1024
# _________________________________________________________________
# dropout_74 (Dropout)         (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_100 (Bat (None, 128)               512
# _________________________________________________________________
# dropout_75 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,754,762
# Trainable params: 1,746,826
# Non-trainable params: 7,936
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 2s 36us/step - loss: 16.6690 - accuracy: 0.1476 - val_loss: 16.0693 - val_accuracy: 0.1519
# Epoch 2/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 16.3229 - accuracy: 0.2026 - val_loss: 15.9080 - val_accuracy: 0.2006
# Epoch 3/25
# 50000/50000 [==============================] - 1s 24us/step - loss: 16.0893 - accuracy: 0.2363 - val_loss: 15.7309 - val_accuracy: 0.2462
# Epoch 4/25
# 50000/50000 [==============================] - 1s 24us/step - loss: 15.9116 - accuracy: 0.2575 - val_loss: 15.5604 - val_accuracy: 0.2857
# Epoch 5/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 15.7490 - accuracy: 0.2750 - val_loss: 15.4018 - val_accuracy: 0.3132
# Epoch 6/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 15.6094 - accuracy: 0.2845 - val_loss: 15.2529 - val_accuracy: 0.3317
# Epoch 7/25
# 50000/50000 [==============================] - 1s 24us/step - loss: 15.4532 - accuracy: 0.3007 - val_loss: 15.1158 - val_accuracy: 0.3506
# Epoch 8/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 15.3139 - accuracy: 0.3107 - val_loss: 14.9860 - val_accuracy: 0.3621
# Epoch 9/25
# 50000/50000 [==============================] - 1s 24us/step - loss: 15.1844 - accuracy: 0.3136 - val_loss: 14.8608 - val_accuracy: 0.3723
# Epoch 10/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 15.0554 - accuracy: 0.3242 - val_loss: 14.7366 - val_accuracy: 0.3813
# Epoch 11/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.9296 - accuracy: 0.3306 - val_loss: 14.6169 - val_accuracy: 0.3905
# Epoch 12/25
# 50000/50000 [==============================] - 1s 24us/step - loss: 14.7987 - accuracy: 0.3384 - val_loss: 14.4966 - val_accuracy: 0.3970
# Epoch 13/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.6720 - accuracy: 0.3442 - val_loss: 14.3783 - val_accuracy: 0.4002
# Epoch 14/25
# 50000/50000 [==============================] - 1s 24us/step - loss: 14.5433 - accuracy: 0.3510 - val_loss: 14.2606 - val_accuracy: 0.4053
# Epoch 15/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.4255 - accuracy: 0.3542 - val_loss: 14.1453 - val_accuracy: 0.4112
# Epoch 16/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.2987 - accuracy: 0.3589 - val_loss: 14.0305 - val_accuracy: 0.4158
# Epoch 17/25
# 50000/50000 [==============================] - 1s 24us/step - loss: 14.1840 - accuracy: 0.3680 - val_loss: 13.9166 - val_accuracy: 0.4215
# Epoch 18/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.0641 - accuracy: 0.3683 - val_loss: 13.8031 - val_accuracy: 0.4264
# Epoch 19/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.9437 - accuracy: 0.3773 - val_loss: 13.6933 - val_accuracy: 0.4258
# Epoch 20/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.8333 - accuracy: 0.3782 - val_loss: 13.5837 - val_accuracy: 0.4314
# Epoch 21/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.7258 - accuracy: 0.3779 - val_loss: 13.4745 - val_accuracy: 0.4328
# Epoch 22/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.6132 - accuracy: 0.3853 - val_loss: 13.3670 - val_accuracy: 0.4369
# Epoch 23/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.5015 - accuracy: 0.3894 - val_loss: 13.2599 - val_accuracy: 0.4398
# Epoch 24/25
# 50000/50000 [==============================] - 1s 24us/step - loss: 13.3853 - accuracy: 0.3918 - val_loss: 13.1542 - val_accuracy: 0.4417
# Epoch 25/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.2814 - accuracy: 0.3940 - val_loss: 13.0487 - val_accuracy: 0.4455
# Numbers of exp: 25, reduce_factor: 0.90, reduce_patient: 5
# Model: "model_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_26 (InputLayer)        (None, 3072)              0
# _________________________________________________________________
# batch_normalization_101 (Bat (None, 3072)              12288
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_102 (Bat (None, 512)               2048
# _________________________________________________________________
# dropout_76 (Dropout)         (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_103 (Bat (None, 256)               1024
# _________________________________________________________________
# dropout_77 (Dropout)         (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_104 (Bat (None, 128)               512
# _________________________________________________________________
# dropout_78 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,754,762
# Trainable params: 1,746,826
# Non-trainable params: 7,936
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 2s 36us/step - loss: 16.7558 - accuracy: 0.1432 - val_loss: 16.0739 - val_accuracy: 0.1611
# Epoch 2/25
# 50000/50000 [==============================] - 1s 24us/step - loss: 16.3782 - accuracy: 0.1997 - val_loss: 15.9076 - val_accuracy: 0.2055
# Epoch 3/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 16.1497 - accuracy: 0.2305 - val_loss: 15.7412 - val_accuracy: 0.2483
# Epoch 4/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 15.9598 - accuracy: 0.2542 - val_loss: 15.5740 - val_accuracy: 0.2892
# Epoch 5/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 15.8010 - accuracy: 0.2709 - val_loss: 15.4203 - val_accuracy: 0.3161
# Epoch 6/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 15.6460 - accuracy: 0.2872 - val_loss: 15.2775 - val_accuracy: 0.3386
# Epoch 7/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 15.5063 - accuracy: 0.2950 - val_loss: 15.1453 - val_accuracy: 0.3549
# Epoch 8/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 15.3715 - accuracy: 0.3069 - val_loss: 15.0196 - val_accuracy: 0.3660
# Epoch 9/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 15.2352 - accuracy: 0.3155 - val_loss: 14.8981 - val_accuracy: 0.3764
# Epoch 10/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 15.1087 - accuracy: 0.3230 - val_loss: 14.7792 - val_accuracy: 0.3871
# Epoch 11/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.9875 - accuracy: 0.3301 - val_loss: 14.6616 - val_accuracy: 0.3943
# Epoch 12/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.8655 - accuracy: 0.3353 - val_loss: 14.5458 - val_accuracy: 0.4001
# Epoch 13/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.7430 - accuracy: 0.3424 - val_loss: 14.4312 - val_accuracy: 0.4041
# Epoch 14/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.6177 - accuracy: 0.3491 - val_loss: 14.3187 - val_accuracy: 0.4086
# Epoch 15/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.5084 - accuracy: 0.3542 - val_loss: 14.2059 - val_accuracy: 0.4152
# Epoch 16/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.3858 - accuracy: 0.3583 - val_loss: 14.0939 - val_accuracy: 0.4201
# Epoch 17/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.2655 - accuracy: 0.3631 - val_loss: 13.9820 - val_accuracy: 0.4243
# Epoch 18/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.1562 - accuracy: 0.3663 - val_loss: 13.8725 - val_accuracy: 0.4280
# Epoch 19/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.0395 - accuracy: 0.3729 - val_loss: 13.7636 - val_accuracy: 0.4309
# Epoch 20/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.9246 - accuracy: 0.3772 - val_loss: 13.6545 - val_accuracy: 0.4357
# Epoch 21/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.8143 - accuracy: 0.3792 - val_loss: 13.5456 - val_accuracy: 0.4380
# Epoch 22/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.7011 - accuracy: 0.3827 - val_loss: 13.4401 - val_accuracy: 0.4422
# Epoch 23/25
# 50000/50000 [==============================] - 1s 24us/step - loss: 13.5919 - accuracy: 0.3883 - val_loss: 13.3356 - val_accuracy: 0.4437
# Epoch 24/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.4779 - accuracy: 0.3908 - val_loss: 13.2322 - val_accuracy: 0.4489
# Epoch 25/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.3747 - accuracy: 0.3918 - val_loss: 13.1287 - val_accuracy: 0.4482
# Numbers of exp: 26, reduce_factor: 0.90, reduce_patient: 9
# Model: "model_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_27 (InputLayer)        (None, 3072)              0
# _________________________________________________________________
# batch_normalization_105 (Bat (None, 3072)              12288
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_106 (Bat (None, 512)               2048
# _________________________________________________________________
# dropout_79 (Dropout)         (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_107 (Bat (None, 256)               1024
# _________________________________________________________________
# dropout_80 (Dropout)         (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_108 (Bat (None, 128)               512
# _________________________________________________________________
# dropout_81 (Dropout)         (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,754,762
# Trainable params: 1,746,826
# Non-trainable params: 7,936
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 2s 37us/step - loss: 16.7285 - accuracy: 0.1455 - val_loss: 16.0721 - val_accuracy: 0.1638
# Epoch 2/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 16.3455 - accuracy: 0.2028 - val_loss: 15.8947 - val_accuracy: 0.2316
# Epoch 3/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 16.1197 - accuracy: 0.2358 - val_loss: 15.7136 - val_accuracy: 0.2715
# Epoch 4/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 15.9246 - accuracy: 0.2610 - val_loss: 15.5423 - val_accuracy: 0.3032
# Epoch 5/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 15.7619 - accuracy: 0.2779 - val_loss: 15.3861 - val_accuracy: 0.3298
# Epoch 6/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 15.6094 - accuracy: 0.2938 - val_loss: 15.2456 - val_accuracy: 0.3489
# Epoch 7/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 15.4760 - accuracy: 0.2997 - val_loss: 15.1121 - val_accuracy: 0.3655
# Epoch 8/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 15.3354 - accuracy: 0.3105 - val_loss: 14.9868 - val_accuracy: 0.3747
# Epoch 9/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 15.2036 - accuracy: 0.3188 - val_loss: 14.8636 - val_accuracy: 0.3845
# Epoch 10/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 15.0682 - accuracy: 0.3274 - val_loss: 14.7415 - val_accuracy: 0.3926
# Epoch 11/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.9404 - accuracy: 0.3375 - val_loss: 14.6240 - val_accuracy: 0.3990
# Epoch 12/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 14.8223 - accuracy: 0.3419 - val_loss: 14.5063 - val_accuracy: 0.4028
# Epoch 13/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.6964 - accuracy: 0.3447 - val_loss: 14.3885 - val_accuracy: 0.4060
# Epoch 14/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.5710 - accuracy: 0.3516 - val_loss: 14.2724 - val_accuracy: 0.4117
# Epoch 15/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.4533 - accuracy: 0.3581 - val_loss: 14.1586 - val_accuracy: 0.4143
# Epoch 16/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.3318 - accuracy: 0.3622 - val_loss: 14.0441 - val_accuracy: 0.4206
# Epoch 17/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.2086 - accuracy: 0.3656 - val_loss: 13.9315 - val_accuracy: 0.4246
# Epoch 18/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.1010 - accuracy: 0.3707 - val_loss: 13.8209 - val_accuracy: 0.4262
# Epoch 19/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.9846 - accuracy: 0.3748 - val_loss: 13.7102 - val_accuracy: 0.4314
# Epoch 20/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.8638 - accuracy: 0.3796 - val_loss: 13.6022 - val_accuracy: 0.4332
# Epoch 21/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.7552 - accuracy: 0.3818 - val_loss: 13.4934 - val_accuracy: 0.4366
# Epoch 22/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.6420 - accuracy: 0.3851 - val_loss: 13.3853 - val_accuracy: 0.4397
# Epoch 23/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.5298 - accuracy: 0.3889 - val_loss: 13.2788 - val_accuracy: 0.4417
# Epoch 24/25
# 50000/50000 [==============================] - 1s 25us/step - loss: 13.4174 - accuracy: 0.3929 - val_loss: 13.1749 - val_accuracy: 0.4445
# Epoch 25/25
# 50000/50000 [==============================] - 1s 26us/step - loss: 13.3099 - accuracy: 0.3969 - val_loss: 13.0687 - val_accuracy: 0.4469

# %%
import matplotlib.pyplot as plt
import matplotlib.cm as mplcm
import matplotlib.colors as colors
# %matplotlib inline
NUM_COLORS = len(results.keys())

cm = plt.get_cmap('gist_rainbow')
cNorm  = colors.Normalize(vmin=0, vmax=NUM_COLORS-1)
scalarMap = mplcm.ScalarMappable(norm=cNorm, cmap=cm)
color_bar = [scalarMap.to_rgba(i) for i in range(NUM_COLORS)]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
