# %% [markdown]
# ## Work
# 1. 請比較 SGD optimizer 不同的 momentum 及使用 nesterov 與否的表現

# %%
import os
import keras

# 本作業可以不需使用 GPU, 將 GPU 設定為 "無" (若想使用可自行開啟)
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# 資料前處理 - X 標準化
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# 資料前處理 -Y 轉成 onehot
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer" + str(i+1))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer" + str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-3
EPOCHS = 50
BATCH_SIZE = 256
MOMENTUM = [0.8, 0.85, 0.9, 0.95]
nesterov = [False, True]

# %%
results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
for nest in nesterov:
    for mmt in MOMENTUM:
        keras.backend.clear_session() # 把舊的 Graph 清掉
        print("Experiment with momentum = %.2f" % (mmt))
        model = build_mlp(input_shape=x_train.shape[1:])
        model.summary()
        optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=nest, momentum=mmt)
        model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

        model.fit(x_train, y_train, 
                  epochs=EPOCHS, 
                  batch_size=BATCH_SIZE, 
                  validation_data=(x_test, y_test), 
                  shuffle=True)

        # Collect results
        train_loss = model.history.history["loss"]
        valid_loss = model.history.history["val_loss"]
        train_acc = model.history.history["accuracy"]
        valid_acc = model.history.history["val_accuracy"]
        
        state = lambda x : "True" if x == 1 else "False"
        exp_name_tag = "Momentum-%s Nesterov-%s" % (str(mmt), state(nest))
        results[exp_name_tag] = {'train-loss': train_loss,
                                 'valid-loss': valid_loss,
                                 'train-acc': train_acc,
                                 'valid-acc': valid_acc}
# Out:
#  accuracy: 0.5057 - val_loss: 1.4673 - val_accuracy: 0.4756
# Epoch 31/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.4020 - accuracy: 0.5072 - val_loss: 1.4754 - val_accuracy: 0.4705
# Epoch 32/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3941 - accuracy: 0.5101 - val_loss: 1.4576 - val_accuracy: 0.4784
# Epoch 33/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3858 - accuracy: 0.5120 - val_loss: 1.4444 - val_accuracy: 0.4844
# Epoch 34/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3766 - accuracy: 0.5161 - val_loss: 1.4354 - val_accuracy: 0.4876
# Epoch 35/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3693 - accuracy: 0.5191 - val_loss: 1.4700 - val_accuracy: 0.4719
# Epoch 36/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3606 - accuracy: 0.5214 - val_loss: 1.4500 - val_accuracy: 0.4816
# Epoch 37/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3536 - accuracy: 0.5230 - val_loss: 1.4632 - val_accuracy: 0.4860
# Epoch 38/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3454 - accuracy: 0.5265 - val_loss: 1.4224 - val_accuracy: 0.4933
# Epoch 39/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3372 - accuracy: 0.5300 - val_loss: 1.4225 - val_accuracy: 0.4944
# Epoch 40/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3300 - accuracy: 0.5319 - val_loss: 1.4184 - val_accuracy: 0.4947
# Epoch 41/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3227 - accuracy: 0.5365 - val_loss: 1.4024 - val_accuracy: 0.5003
# Epoch 42/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3154 - accuracy: 0.5378 - val_loss: 1.4043 - val_accuracy: 0.4998
# Epoch 43/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3074 - accuracy: 0.5401 - val_loss: 1.3995 - val_accuracy: 0.5016
# Epoch 44/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.2998 - accuracy: 0.5445 - val_loss: 1.4306 - val_accuracy: 0.4933
# Epoch 45/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.2931 - accuracy: 0.5451 - val_loss: 1.3973 - val_accuracy: 0.5053
# Epoch 46/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.2862 - accuracy: 0.5471 - val_loss: 1.4335 - val_accuracy: 0.4893
# Epoch 47/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.2790 - accuracy: 0.5497 - val_loss: 1.4147 - val_accuracy: 0.5025
# Epoch 48/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.2717 - accuracy: 0.5503 - val_loss: 1.4056 - val_accuracy: 0.5002
# Epoch 49/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.2665 - accuracy: 0.5529 - val_loss: 1.4527 - val_accuracy: 0.4917
# Epoch 50/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.2599 - accuracy: 0.5560 - val_loss: 1.4190 - val_accuracy: 0.4976
# Experiment with momentum = 0.90
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 2s 32us/step - loss: 2.0871 - accuracy: 0.2628 - val_loss: 1.9432 - val_accuracy: 0.3195
# Epoch 2/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.8863 - accuracy: 0.3393 - val_loss: 1.8453 - val_accuracy: 0.3554
# Epoch 3/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.8084 - accuracy: 0.3674 - val_loss: 1.7809 - val_accuracy: 0.3769
# Epoch 4/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.7547 - accuracy: 0.3857 - val_loss: 1.7342 - val_accuracy: 0.3880
# Epoch 5/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.7114 - accuracy: 0.4036 - val_loss: 1.6994 - val_accuracy: 0.4043
# Epoch 6/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.6761 - accuracy: 0.4130 - val_loss: 1.6730 - val_accuracy: 0.4114
# Epoch 7/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.6477 - accuracy: 0.4251 - val_loss: 1.6412 - val_accuracy: 0.4243
# Epoch 8/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.6204 - accuracy: 0.4346 - val_loss: 1.6201 - val_accuracy: 0.4332
# Epoch 9/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.5967 - accuracy: 0.4426 - val_loss: 1.6016 - val_accuracy: 0.4352
# Epoch 10/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.5752 - accuracy: 0.4504 - val_loss: 1.5719 - val_accuracy: 0.4478
# Epoch 11/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.5548 - accuracy: 0.4589 - val_loss: 1.5638 - val_accuracy: 0.4480
# Epoch 12/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.5378 - accuracy: 0.4634 - val_loss: 1.5501 - val_accuracy: 0.4521
# Epoch 13/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.5203 - accuracy: 0.4684 - val_loss: 1.5343 - val_accuracy: 0.4608
# Epoch 14/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.5043 - accuracy: 0.4743 - val_loss: 1.5330 - val_accuracy: 0.4539
# Epoch 15/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.4885 - accuracy: 0.4802 - val_loss: 1.5100 - val_accuracy: 0.4686
# Epoch 16/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.4731 - accuracy: 0.4847 - val_loss: 1.5055 - val_accuracy: 0.4656
# Epoch 17/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.4583 - accuracy: 0.4909 - val_loss: 1.4874 - val_accuracy: 0.4737
# Epoch 18/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.4441 - accuracy: 0.4961 - val_loss: 1.4762 - val_accuracy: 0.4776
# Epoch 19/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.4316 - accuracy: 0.5001 - val_loss: 1.4682 - val_accuracy: 0.4838
# Epoch 20/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.4184 - accuracy: 0.5046 - val_loss: 1.4556 - val_accuracy: 0.4853
# Epoch 21/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.4042 - accuracy: 0.5094 - val_loss: 1.4449 - val_accuracy: 0.4883
# Epoch 22/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.3919 - accuracy: 0.5140 - val_loss: 1.4687 - val_accuracy: 0.4808
# Epoch 23/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.3795 - accuracy: 0.5178 - val_loss: 1.4512 - val_accuracy: 0.4889
# Epoch 24/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3674 - accuracy: 0.5237 - val_loss: 1.4303 - val_accuracy: 0.4901
# Epoch 25/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3560 - accuracy: 0.5250 - val_loss: 1.4195 - val_accuracy: 0.4918
# Epoch 26/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3441 - accuracy: 0.5293 - val_loss: 1.4136 - val_accuracy: 0.4997
# Epoch 27/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3344 - accuracy: 0.5329 - val_loss: 1.4246 - val_accuracy: 0.4969
# Epoch 28/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3234 - accuracy: 0.5370 - val_loss: 1.4088 - val_accuracy: 0.5010
# Epoch 29/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3139 - accuracy: 0.5408 - val_loss: 1.4033 - val_accuracy: 0.4996
# Epoch 30/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3012 - accuracy: 0.5456 - val_loss: 1.3945 - val_accuracy: 0.5027
# Epoch 31/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.2910 - accuracy: 0.5470 - val_loss: 1.4021 - val_accuracy: 0.4977
# Epoch 32/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.2824 - accuracy: 0.5515 - val_loss: 1.4109 - val_accuracy: 0.5019
# Epoch 33/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.2718 - accuracy: 0.5558 - val_loss: 1.3809 - val_accuracy: 0.5093
# Epoch 34/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.2630 - accuracy: 0.5559 - val_loss: 1.3675 - val_accuracy: 0.5138
# Epoch 35/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.2526 - accuracy: 0.5621 - val_loss: 1.3759 - val_accuracy: 0.5113
# Epoch 36/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.2417 - accuracy: 0.5640 - val_loss: 1.3855 - val_accuracy: 0.5156
# Epoch 37/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.2365 - accuracy: 0.5693 - val_loss: 1.3913 - val_accuracy: 0.5137
# Epoch 38/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.2267 - accuracy: 0.5694 - val_loss: 1.3732 - val_accuracy: 0.5090
# Epoch 39/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.2147 - accuracy: 0.5754 - val_loss: 1.4288 - val_accuracy: 0.4977
# Epoch 40/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.2069 - accuracy: 0.5778 - val_loss: 1.3814 - val_accuracy: 0.5129
# Epoch 41/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.1979 - accuracy: 0.5806 - val_loss: 1.3799 - val_accuracy: 0.5080
# Epoch 42/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.1927 - accuracy: 0.5825 - val_loss: 1.3616 - val_accuracy: 0.5216
# Epoch 43/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.1820 - accuracy: 0.5848 - val_loss: 1.3559 - val_accuracy: 0.5155
# Epoch 44/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.1726 - accuracy: 0.5892 - val_loss: 1.3756 - val_accuracy: 0.5123
# Epoch 45/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.1654 - accuracy: 0.5921 - val_loss: 1.3592 - val_accuracy: 0.5162
# Epoch 46/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.1539 - accuracy: 0.5958 - val_loss: 1.3691 - val_accuracy: 0.5163
# Epoch 47/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.1480 - accuracy: 0.5982 - val_loss: 1.3919 - val_accuracy: 0.5125
# Epoch 48/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.1401 - accuracy: 0.5999 - val_loss: 1.4166 - val_accuracy: 0.4982
# Epoch 49/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.1296 - accuracy: 0.6043 - val_loss: 1.3848 - val_accuracy: 0.5100
# Epoch 50/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.1234 - accuracy: 0.6056 - val_loss: 1.3302 - val_accuracy: 0.5311
# Experiment with momentum = 0.95
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,738,890
# Trainable params: 1,738,890
# Non-trainable params: 0
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/50
# 50000/50000 [==============================] - 2s 32us/step - loss: 2.0254 - accuracy: 0.2784 - val_loss: 1.8652 - val_accuracy: 0.3466
# Epoch 2/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.8099 - accuracy: 0.3675 - val_loss: 1.7629 - val_accuracy: 0.3873
# Epoch 3/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.7273 - accuracy: 0.3964 - val_loss: 1.6891 - val_accuracy: 0.4135
# Epoch 4/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.6686 - accuracy: 0.4157 - val_loss: 1.6422 - val_accuracy: 0.4236
# Epoch 5/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.6195 - accuracy: 0.4329 - val_loss: 1.6102 - val_accuracy: 0.4332
# Epoch 6/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.5791 - accuracy: 0.4470 - val_loss: 1.5799 - val_accuracy: 0.4450
# Epoch 7/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.5451 - accuracy: 0.4580 - val_loss: 1.5450 - val_accuracy: 0.4536
# Epoch 8/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.5129 - accuracy: 0.4689 - val_loss: 1.5153 - val_accuracy: 0.4693
# Epoch 9/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.4858 - accuracy: 0.4786 - val_loss: 1.5048 - val_accuracy: 0.4656
# Epoch 10/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.4592 - accuracy: 0.4880 - val_loss: 1.4901 - val_accuracy: 0.4705
# Epoch 11/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.4359 - accuracy: 0.4957 - val_loss: 1.4732 - val_accuracy: 0.4774
# Epoch 12/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.4141 - accuracy: 0.5018 - val_loss: 1.4643 - val_accuracy: 0.4752
# Epoch 13/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.3915 - accuracy: 0.5093 - val_loss: 1.4569 - val_accuracy: 0.4867
# Epoch 14/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3712 - accuracy: 0.5168 - val_loss: 1.4253 - val_accuracy: 0.4938
# Epoch 15/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3517 - accuracy: 0.5236 - val_loss: 1.4591 - val_accuracy: 0.4772
# Epoch 16/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.3345 - accuracy: 0.5312 - val_loss: 1.4019 - val_accuracy: 0.4940
# Epoch 17/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.3138 - accuracy: 0.5342 - val_loss: 1.3919 - val_accuracy: 0.5030
# Epoch 18/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.2990 - accuracy: 0.5395 - val_loss: 1.4271 - val_accuracy: 0.4949
# Epoch 19/50
# 50000/50000 [==============================] - 2s 31us/step - loss: 1.2831 - accuracy: 0.5493 - val_loss: 1.3839 - val_accuracy: 0.5087
# Epoch 20/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.2670 - accuracy: 0.5528 - val_loss: 1.4139 - val_accuracy: 0.5015
# Epoch 21/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.2499 - accuracy: 0.5588 - val_loss: 1.3611 - val_accuracy: 0.5174
# Epoch 22/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.2356 - accuracy: 0.5638 - val_loss: 1.3519 - val_accuracy: 0.5229
# Epoch 23/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.2201 - accuracy: 0.5690 - val_loss: 1.3781 - val_accuracy: 0.5169
# Epoch 24/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.2091 - accuracy: 0.5711 - val_loss: 1.3767 - val_accuracy: 0.5145
# Epoch 25/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.1924 - accuracy: 0.5802 - val_loss: 1.3932 - val_accuracy: 0.4996
# Epoch 26/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.1788 - accuracy: 0.5835 - val_loss: 1.3898 - val_accuracy: 0.5139
# Epoch 27/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.1653 - accuracy: 0.5882 - val_loss: 1.3842 - val_accuracy: 0.5162
# Epoch 28/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.1531 - accuracy: 0.5937 - val_loss: 1.3736 - val_accuracy: 0.5133
# Epoch 29/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.1382 - accuracy: 0.5997 - val_loss: 1.3347 - val_accuracy: 0.5292
# Epoch 30/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.1276 - accuracy: 0.6021 - val_loss: 1.3604 - val_accuracy: 0.5238
# Epoch 31/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.1113 - accuracy: 0.6082 - val_loss: 1.3571 - val_accuracy: 0.5245
# Epoch 32/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.1019 - accuracy: 0.6125 - val_loss: 1.3879 - val_accuracy: 0.5186
# Epoch 33/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.0907 - accuracy: 0.6163 - val_loss: 1.3976 - val_accuracy: 0.5214
# Epoch 34/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.0748 - accuracy: 0.6220 - val_loss: 1.3541 - val_accuracy: 0.5325
# Epoch 35/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.0607 - accuracy: 0.6265 - val_loss: 1.3450 - val_accuracy: 0.5307
# Epoch 36/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.0495 - accuracy: 0.6304 - val_loss: 1.3408 - val_accuracy: 0.5295
# Epoch 37/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.0357 - accuracy: 0.6329 - val_loss: 1.3320 - val_accuracy: 0.5331
# Epoch 38/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 1.0263 - accuracy: 0.6392 - val_loss: 1.3270 - val_accuracy: 0.5367
# Epoch 39/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.0107 - accuracy: 0.6441 - val_loss: 1.3682 - val_accuracy: 0.5227
# Epoch 40/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 1.0070 - accuracy: 0.6466 - val_loss: 1.3698 - val_accuracy: 0.5294
# Epoch 41/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 0.9869 - accuracy: 0.6538 - val_loss: 1.3838 - val_accuracy: 0.5253
# Epoch 42/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 0.9776 - accuracy: 0.6564 - val_loss: 1.3784 - val_accuracy: 0.5277
# Epoch 43/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.9655 - accuracy: 0.6608 - val_loss: 1.3457 - val_accuracy: 0.5392
# Epoch 44/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.9523 - accuracy: 0.6659 - val_loss: 1.4294 - val_accuracy: 0.5124
# Epoch 45/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.9427 - accuracy: 0.6680 - val_loss: 1.4207 - val_accuracy: 0.5192
# Epoch 46/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.9316 - accuracy: 0.6718 - val_loss: 1.3514 - val_accuracy: 0.5368
# Epoch 47/50
# 50000/50000 [==============================] - 2s 30us/step - loss: 0.9186 - accuracy: 0.6771 - val_loss: 1.4707 - val_accuracy: 0.5104
# Epoch 48/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.9108 - accuracy: 0.6812 - val_loss: 1.3538 - val_accuracy: 0.5363
# Epoch 49/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.8949 - accuracy: 0.6851 - val_loss: 1.3852 - val_accuracy: 0.5377
# Epoch 50/50
# 50000/50000 [==============================] - 1s 30us/step - loss: 0.8801 - accuracy: 0.6915 - val_loss: 1.4074 - val_accuracy: 0.5300

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
import matplotlib.pyplot as plt
# %matplotlib inline
color_bar = ["r", "g", "b", "y", "m", "k", "c", 'burlywood', 'chartreuse', "lightblue"]

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-loss'])),results[cond]['train-loss'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-loss'])),results[cond]['valid-loss'], '--', label=cond, color=color_bar[i])
plt.title("Loss")
plt.legend()
plt.show()

plt.figure(figsize=(8,6))
for i, cond in enumerate(results.keys()):
    plt.plot(range(len(results[cond]['train-acc'])),results[cond]['train-acc'], '-', label=cond, color=color_bar[i])
    plt.plot(range(len(results[cond]['valid-acc'])),results[cond]['valid-acc'], '--', label=cond, color=color_bar[i])
plt.title("Accuracy")
plt.legend()
plt.show()
