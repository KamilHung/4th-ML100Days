# %% [markdown]
# ## Work
# 1. 請嘗試將 preproc_x 替換成以每筆資料的 min/max 進行標準化至 -1 ~ 1 間，再進行訓練
# 2. 請嘗試將 mlp 疊更深 (e.g 5~10 層)，進行訓練後觀察 learning curve 的走勢
# 3. (optional) 請改用 GPU 進行訓練 (如果你有 GPU 的話)，比較使用 CPU 與 GPU 的訓練速度

# %%
## 
"""
Your code here (optional)
確認硬體資源
"""
! nvidia-smi
# Out:
# 'nvidia-smi' ���O�����Υ~���R�O�B�i���檺�{���Χ妸�ɡC

# %%
import os
import keras

# 請嘗試設定 GPU：os.environ
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
"""
Your code here
"""
from sklearn.preprocessing import MinMaxScaler
MMscaler = MinMaxScaler(feature_range = (-1, 1))
def preproc_x(x):
    x = x / 255
    x = x.reshape((len(x), -1))
    x = MMscaler.fit_transform(x)
    return x

def preproc_y(y, num_classes = 10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
"""Code Here
建立你的神經網路
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(input_layer)
        else:
            x = keras.layers.Dense(units=n_units, activation="relu", name="hidden_layer"+str(i+1))(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

model = build_mlp(input_shape=x_train.shape[1:], output_units = 10,
                  num_neurons = [512, 256, 128, 64, 32, 16])
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# hidden_layer4 (Dense)        (None, 64)                8256
# _________________________________________________________________
# hidden_layer5 (Dense)        (None, 32)                2080
# _________________________________________________________________
# hidden_layer6 (Dense)        (None, 16)                528
# _________________________________________________________________
# output (Dense)               (None, 10)                170
# =================================================================
# Total params: 1,748,634
# Trainable params: 1,748,634
# Non-trainable params: 0
# _________________________________________________________________

# %%
## 超參數設定
LEARNING_RATE = 0.001
EPOCHS = 100
BATCH_SIZE = 256

# %%
optimizer = keras.optimizers.Adam(lr=LEARNING_RATE)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

# %%
model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True)
# Out:
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/100
# 50000/50000 [==============================] - 3s 53us/step - loss: 1.7894 - accuracy: 0.3676 - val_loss: 1.5864 - val_accuracy: 0.4385
# Epoch 2/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 1.5246 - accuracy: 0.4631 - val_loss: 1.5128 - val_accuracy: 0.4648
# Epoch 3/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 1.4055 - accuracy: 0.5043 - val_loss: 1.4342 - val_accuracy: 0.4916
# Epoch 4/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 1.3084 - accuracy: 0.5400 - val_loss: 1.4122 - val_accuracy: 0.5057
# Epoch 5/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 1.2234 - accuracy: 0.5700 - val_loss: 1.3989 - val_accuracy: 0.5156
# Epoch 6/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 1.1512 - accuracy: 0.5936 - val_loss: 1.3959 - val_accuracy: 0.5163
# Epoch 7/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 1.0807 - accuracy: 0.6197 - val_loss: 1.3671 - val_accuracy: 0.5331
# Epoch 8/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.9992 - accuracy: 0.6472 - val_loss: 1.4111 - val_accuracy: 0.5260
# Epoch 9/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.9353 - accuracy: 0.6725 - val_loss: 1.4057 - val_accuracy: 0.5404
# Epoch 10/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.8710 - accuracy: 0.6922 - val_loss: 1.4610 - val_accuracy: 0.5331
# Epoch 11/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.8104 - accuracy: 0.7137 - val_loss: 1.4914 - val_accuracy: 0.5287
# Epoch 12/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.7467 - accuracy: 0.7357 - val_loss: 1.5600 - val_accuracy: 0.5327
# Epoch 13/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.6958 - accuracy: 0.7546 - val_loss: 1.5738 - val_accuracy: 0.5342
# Epoch 14/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.6323 - accuracy: 0.7778 - val_loss: 1.6706 - val_accuracy: 0.5376
# Epoch 15/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.5924 - accuracy: 0.7899 - val_loss: 1.7277 - val_accuracy: 0.5279
# Epoch 16/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.5408 - accuracy: 0.8091 - val_loss: 1.8167 - val_accuracy: 0.5248
# Epoch 17/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.4976 - accuracy: 0.8236 - val_loss: 1.8825 - val_accuracy: 0.5429
# Epoch 18/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.4509 - accuracy: 0.8422 - val_loss: 2.0533 - val_accuracy: 0.5224
# Epoch 19/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.4303 - accuracy: 0.8485 - val_loss: 2.0952 - val_accuracy: 0.5311
# Epoch 20/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.4019 - accuracy: 0.8590 - val_loss: 2.1259 - val_accuracy: 0.5354
# Epoch 21/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.3550 - accuracy: 0.8751 - val_loss: 2.3522 - val_accuracy: 0.5255
# Epoch 22/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.3496 - accuracy: 0.8771 - val_loss: 2.3425 - val_accuracy: 0.5255
# Epoch 23/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.3373 - accuracy: 0.8820 - val_loss: 2.3711 - val_accuracy: 0.5300
# Epoch 24/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.2972 - accuracy: 0.8954 - val_loss: 2.4843 - val_accuracy: 0.5295
# Epoch 25/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.2825 - accuracy: 0.9012 - val_loss: 2.5478 - val_accuracy: 0.5243
# Epoch 26/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.2765 - accuracy: 0.9036 - val_loss: 2.6381 - val_accuracy: 0.5312
# Epoch 27/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.2543 - accuracy: 0.9115 - val_loss: 2.7605 - val_accuracy: 0.5302
# Epoch 28/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.2350 - accuracy: 0.9180 - val_loss: 2.8265 - val_accuracy: 0.5261
# Epoch 29/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.2415 - accuracy: 0.9160 - val_loss: 2.7098 - val_accuracy: 0.5310
# Epoch 30/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.2181 - accuracy: 0.9237 - val_loss: 2.8975 - val_accuracy: 0.5257
# Epoch 31/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.2088 - accuracy: 0.9281 - val_loss: 2.9520 - val_accuracy: 0.5184
# Epoch 32/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1985 - accuracy: 0.9319 - val_loss: 3.0776 - val_accuracy: 0.5328
# Epoch 33/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.2048 - accuracy: 0.9303 - val_loss: 2.9946 - val_accuracy: 0.5277
# Epoch 34/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1903 - accuracy: 0.9349 - val_loss: 3.0814 - val_accuracy: 0.5246
# Epoch 35/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1824 - accuracy: 0.9377 - val_loss: 3.2911 - val_accuracy: 0.5297
# Epoch 36/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1735 - accuracy: 0.9410 - val_loss: 3.0786 - val_accuracy: 0.5302
# Epoch 37/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1761 - accuracy: 0.9393 - val_loss: 3.1651 - val_accuracy: 0.5257
# Epoch 38/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1717 - accuracy: 0.9407 - val_loss: 3.2771 - val_accuracy: 0.5300
# Epoch 39/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1572 - accuracy: 0.9470 - val_loss: 3.4602 - val_accuracy: 0.5268
# Epoch 40/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1542 - accuracy: 0.9470 - val_loss: 3.3161 - val_accuracy: 0.5317
# Epoch 41/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1502 - accuracy: 0.9490 - val_loss: 3.4305 - val_accuracy: 0.5312
# Epoch 42/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1750 - accuracy: 0.9407 - val_loss: 3.2613 - val_accuracy: 0.5268
# Epoch 43/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1335 - accuracy: 0.9562 - val_loss: 3.4619 - val_accuracy: 0.5340
# Epoch 44/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1162 - accuracy: 0.9612 - val_loss: 3.5754 - val_accuracy: 0.5253
# Epoch 45/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1523 - accuracy: 0.9496 - val_loss: 3.4684 - val_accuracy: 0.5241
# Epoch 46/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1467 - accuracy: 0.9500 - val_loss: 3.5907 - val_accuracy: 0.5299
# Epoch 47/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1384 - accuracy: 0.9541 - val_loss: 3.4077 - val_accuracy: 0.5270
# Epoch 48/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1299 - accuracy: 0.9565 - val_loss: 3.5406 - val_accuracy: 0.5274
# Epoch 49/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1196 - accuracy: 0.9601 - val_loss: 3.6220 - val_accuracy: 0.5249
# Epoch 50/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1309 - accuracy: 0.9563 - val_loss: 3.7153 - val_accuracy: 0.5259
# Epoch 51/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1263 - accuracy: 0.9579 - val_loss: 3.5861 - val_accuracy: 0.5320
# Epoch 52/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1185 - accuracy: 0.9610 - val_loss: 3.7445 - val_accuracy: 0.5312
# Epoch 53/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1091 - accuracy: 0.9632 - val_loss: 3.7558 - val_accuracy: 0.5293
# Epoch 54/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1015 - accuracy: 0.9658 - val_loss: 3.8186 - val_accuracy: 0.5284
# Epoch 55/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1121 - accuracy: 0.9626 - val_loss: 3.8376 - val_accuracy: 0.5275
# Epoch 56/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1147 - accuracy: 0.9623 - val_loss: 3.9444 - val_accuracy: 0.5285
# Epoch 57/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1225 - accuracy: 0.9594 - val_loss: 3.8909 - val_accuracy: 0.5305
# Epoch 58/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1088 - accuracy: 0.9639 - val_loss: 3.8555 - val_accuracy: 0.5361
# Epoch 59/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0963 - accuracy: 0.9685 - val_loss: 4.0917 - val_accuracy: 0.5263
# Epoch 60/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1132 - accuracy: 0.9633 - val_loss: 3.9980 - val_accuracy: 0.5306
# Epoch 61/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1126 - accuracy: 0.9630 - val_loss: 3.8715 - val_accuracy: 0.5212
# Epoch 62/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0845 - accuracy: 0.9712 - val_loss: 4.1690 - val_accuracy: 0.5229
# Epoch 63/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0872 - accuracy: 0.9709 - val_loss: 3.9328 - val_accuracy: 0.5279
# Epoch 64/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1167 - accuracy: 0.9622 - val_loss: 3.8181 - val_accuracy: 0.5299
# Epoch 65/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0963 - accuracy: 0.9686 - val_loss: 4.1024 - val_accuracy: 0.5288
# Epoch 66/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0917 - accuracy: 0.9702 - val_loss: 3.9096 - val_accuracy: 0.5252
# Epoch 67/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0837 - accuracy: 0.9731 - val_loss: 3.9688 - val_accuracy: 0.5204
# Epoch 68/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0931 - accuracy: 0.9686 - val_loss: 3.9149 - val_accuracy: 0.5319
# Epoch 69/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0864 - accuracy: 0.9709 - val_loss: 4.0846 - val_accuracy: 0.5325
# Epoch 70/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0911 - accuracy: 0.9693 - val_loss: 4.1165 - val_accuracy: 0.5323
# Epoch 71/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.1001 - accuracy: 0.9681 - val_loss: 4.0209 - val_accuracy: 0.5290
# Epoch 72/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0895 - accuracy: 0.9698 - val_loss: 4.0443 - val_accuracy: 0.5271
# Epoch 73/100
# 50000/50000 [==============================] - 2s 35us/step - loss: 0.0958 - accuracy: 0.9698 - val_loss: 4.1795 - val_accuracy: 0.5256
# Epoch 74/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0933 - accuracy: 0.9695 - val_loss: 3.9516 - val_accuracy: 0.5265
# Epoch 75/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0631 - accuracy: 0.9783 - val_loss: 4.3622 - val_accuracy: 0.5351
# Epoch 76/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0772 - accuracy: 0.9753 - val_loss: 4.1072 - val_accuracy: 0.5271
# Epoch 77/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0816 - accuracy: 0.9738 - val_loss: 4.2875 - val_accuracy: 0.5217
# Epoch 78/100
# 50000/50000 [==============================] - 2s 35us/step - loss: 0.0896 - accuracy: 0.9711 - val_loss: 4.2689 - val_accuracy: 0.5268
# Epoch 79/100
# 50000/50000 [==============================] - 2s 35us/step - loss: 0.0832 - accuracy: 0.9729 - val_loss: 4.1931 - val_accuracy: 0.5290
# Epoch 80/100
# 50000/50000 [==============================] - 2s 35us/step - loss: 0.0674 - accuracy: 0.9787 - val_loss: 4.1213 - val_accuracy: 0.5308
# Epoch 81/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0868 - accuracy: 0.9724 - val_loss: 4.3266 - val_accuracy: 0.5294
# Epoch 82/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0752 - accuracy: 0.9756 - val_loss: 4.0859 - val_accuracy: 0.5338
# Epoch 83/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0907 - accuracy: 0.9706 - val_loss: 4.1979 - val_accuracy: 0.5315
# Epoch 84/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0642 - accuracy: 0.9790 - val_loss: 4.3542 - val_accuracy: 0.5335
# Epoch 85/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0544 - accuracy: 0.9820 - val_loss: 4.3575 - val_accuracy: 0.5271
# Epoch 86/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0935 - accuracy: 0.9695 - val_loss: 4.0726 - val_accuracy: 0.5241
# Epoch 87/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0752 - accuracy: 0.9758 - val_loss: 4.0831 - val_accuracy: 0.5377
# Epoch 88/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0497 - accuracy: 0.9834 - val_loss: 4.4184 - val_accuracy: 0.5270
# Epoch 89/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0754 - accuracy: 0.9758 - val_loss: 4.3319 - val_accuracy: 0.5275
# Epoch 90/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0769 - accuracy: 0.9750 - val_loss: 4.4021 - val_accuracy: 0.5293
# Epoch 91/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0784 - accuracy: 0.9740 - val_loss: 4.2643 - val_accuracy: 0.5335
# Epoch 92/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0563 - accuracy: 0.9826 - val_loss: 4.4962 - val_accuracy: 0.5247
# Epoch 93/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0903 - accuracy: 0.9711 - val_loss: 4.2076 - val_accuracy: 0.5270
# Epoch 94/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0746 - accuracy: 0.9767 - val_loss: 4.2123 - val_accuracy: 0.5310
# Epoch 95/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0593 - accuracy: 0.9811 - val_loss: 4.3048 - val_accuracy: 0.5349
# Epoch 96/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0659 - accuracy: 0.9796 - val_loss: 4.3181 - val_accuracy: 0.5265
# Epoch 97/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0587 - accuracy: 0.9808 - val_loss: 4.3335 - val_accuracy: 0.5307
# Epoch 98/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0706 - accuracy: 0.9768 - val_loss: 4.3482 - val_accuracy: 0.5299
# Epoch 99/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0598 - accuracy: 0.9806 - val_loss: 4.3869 - val_accuracy: 0.5347
# Epoch 100/100
# 50000/50000 [==============================] - 2s 34us/step - loss: 0.0674 - accuracy: 0.9786 - val_loss: 4.2687 - val_accuracy: 0.5327

# %%
import matplotlib.pyplot as plt


train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]

train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()
