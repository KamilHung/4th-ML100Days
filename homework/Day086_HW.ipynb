# %% [markdown]
# ## Work
# 1. 試比較 save_best_only 與否的差異
# 2. 請僅存入將 save_weights_only 設定為 True, 並嘗試 reset ipynb 並將模型與權重重新建回並預測 x_test

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.regularizers import l1_l2

def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128], l1_l2_ratio=1e-8, drp_ratio=0.2):
    """Code Here
    建立你的神經網路
    """
    input_layer = keras.layers.Input(input_shape)
    x = keras.layers.BatchNormalization()(input_layer)
    
    for i, n_units in enumerate(num_neurons):
        x = keras.layers.Dense(units=n_units, 
                               activation="relu", 
                               name="hidden_layer"+str(i+1),
                               kernel_regularizer=l1_l2(l1_l2_ratio))(x)
        x = keras.layers.BatchNormalization()(x)
        x = keras.layers.Dropout(drp_ratio)(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
"""Code Here
設定超參數
"""
LEARNING_RATE = 1e-4
EPOCHS = 80
BATCH_SIZE = 1024

# %%
# 載入 Callbacks
"""Code Here
設定 callbacks: model checkpoint
"""
from keras.callbacks import ModelCheckpoint

model_ckpt = ModelCheckpoint(filepath="./tmp.h5", 
                             monitor="val_loss", 
                             save_best_only=False,
                             save_weights_only=True)

results = {}
"""Code Here
撰寫你的訓練流程並將結果用 dictionary 紀錄
"""
keras.backend.clear_session() # 把舊的 Graph 清掉

model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.Adam(lr=LEARNING_RATE)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[model_ckpt])

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

#model = keras.models.load_model("./saved_models/tmp.h5")
#loss_loadback, acc_loadback = model.evaluate(x_test, y_test)
model.load_weights("./tmp.h5")
loss_loadback, acc_loadback = model.evaluate(x_test, y_test)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 3072)              12288
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 512)               2048
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,754,762
# Trainable params: 1,746,826
# Non-trainable params: 7,936
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/80
# 50000/50000 [==============================] - 2s 43us/step - loss: 15.8481 - accuracy: 0.2598 - val_loss: 15.1666 - val_accuracy: 0.2468
# Epoch 2/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 14.5662 - accuracy: 0.3448 - val_loss: 14.0694 - val_accuracy: 0.3029
# Epoch 3/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 13.4772 - accuracy: 0.3772 - val_loss: 13.0380 - val_accuracy: 0.3286
# Epoch 4/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 12.4550 - accuracy: 0.4024 - val_loss: 12.0616 - val_accuracy: 0.3514
# Epoch 5/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 11.5108 - accuracy: 0.4227 - val_loss: 11.1154 - val_accuracy: 0.3901
# Epoch 6/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 10.6415 - accuracy: 0.4395 - val_loss: 10.2509 - val_accuracy: 0.4168
# Epoch 7/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 9.8457 - accuracy: 0.4534 - val_loss: 9.4595 - val_accuracy: 0.4503
# Epoch 8/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 9.1173 - accuracy: 0.4668 - val_loss: 8.7522 - val_accuracy: 0.4691
# Epoch 9/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 8.4526 - accuracy: 0.4786 - val_loss: 8.1163 - val_accuracy: 0.4813
# Epoch 10/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 7.8540 - accuracy: 0.4856 - val_loss: 7.5423 - val_accuracy: 0.4963
# Epoch 11/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 7.3097 - accuracy: 0.4967 - val_loss: 7.0313 - val_accuracy: 0.5030
# Epoch 12/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 6.8071 - accuracy: 0.5099 - val_loss: 6.5706 - val_accuracy: 0.5079
# Epoch 13/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 6.3566 - accuracy: 0.5168 - val_loss: 6.1413 - val_accuracy: 0.5122
# Epoch 14/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 5.9454 - accuracy: 0.5237 - val_loss: 5.7597 - val_accuracy: 0.5203
# Epoch 15/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 5.5784 - accuracy: 0.5300 - val_loss: 5.4203 - val_accuracy: 0.5187
# Epoch 16/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 5.2305 - accuracy: 0.5398 - val_loss: 5.1013 - val_accuracy: 0.5294
# Epoch 17/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 4.9145 - accuracy: 0.5511 - val_loss: 4.8246 - val_accuracy: 0.5240
# Epoch 18/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 4.6419 - accuracy: 0.5535 - val_loss: 4.5584 - val_accuracy: 0.5322
# Epoch 19/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 4.3761 - accuracy: 0.5595 - val_loss: 4.3347 - val_accuracy: 0.5318
# Epoch 20/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 4.1371 - accuracy: 0.5704 - val_loss: 4.1075 - val_accuracy: 0.5403
# Epoch 21/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 3.9207 - accuracy: 0.5755 - val_loss: 3.9232 - val_accuracy: 0.5375
# Epoch 22/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 3.7192 - accuracy: 0.5822 - val_loss: 3.7492 - val_accuracy: 0.5328
# Epoch 23/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 3.5399 - accuracy: 0.5878 - val_loss: 3.5699 - val_accuracy: 0.5431
# Epoch 24/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 3.3676 - accuracy: 0.5941 - val_loss: 3.4200 - val_accuracy: 0.5487
# Epoch 25/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 3.2136 - accuracy: 0.5999 - val_loss: 3.3086 - val_accuracy: 0.5389
# Epoch 26/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 3.0808 - accuracy: 0.6018 - val_loss: 3.1653 - val_accuracy: 0.5443
# Epoch 27/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.9394 - accuracy: 0.6106 - val_loss: 3.0472 - val_accuracy: 0.5475
# Epoch 28/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.8197 - accuracy: 0.6156 - val_loss: 2.9481 - val_accuracy: 0.5483
# Epoch 29/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.7023 - accuracy: 0.6228 - val_loss: 2.8479 - val_accuracy: 0.5510
# Epoch 30/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.5944 - accuracy: 0.6289 - val_loss: 2.7673 - val_accuracy: 0.5480
# Epoch 31/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4946 - accuracy: 0.6358 - val_loss: 2.6851 - val_accuracy: 0.5524
# Epoch 32/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.4017 - accuracy: 0.6418 - val_loss: 2.6103 - val_accuracy: 0.5509
# Epoch 33/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.3275 - accuracy: 0.6419 - val_loss: 2.5401 - val_accuracy: 0.5519
# Epoch 34/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.2340 - accuracy: 0.6542 - val_loss: 2.4669 - val_accuracy: 0.5592
# Epoch 35/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.1638 - accuracy: 0.6562 - val_loss: 2.4147 - val_accuracy: 0.5572
# Epoch 36/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 2.0996 - accuracy: 0.6590 - val_loss: 2.3641 - val_accuracy: 0.5527
# Epoch 37/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 2.0279 - accuracy: 0.6667 - val_loss: 2.3092 - val_accuracy: 0.5591
# Epoch 38/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.9646 - accuracy: 0.6716 - val_loss: 2.2601 - val_accuracy: 0.5587
# Epoch 39/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.9081 - accuracy: 0.6744 - val_loss: 2.2218 - val_accuracy: 0.5572
# Epoch 40/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.8546 - accuracy: 0.6794 - val_loss: 2.2012 - val_accuracy: 0.5560
# Epoch 41/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.8031 - accuracy: 0.6855 - val_loss: 2.1486 - val_accuracy: 0.5609
# Epoch 42/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.7567 - accuracy: 0.6888 - val_loss: 2.1092 - val_accuracy: 0.5595
# Epoch 43/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.7066 - accuracy: 0.6940 - val_loss: 2.0966 - val_accuracy: 0.5599
# Epoch 44/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.6647 - accuracy: 0.6991 - val_loss: 2.0560 - val_accuracy: 0.5694
# Epoch 45/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.6156 - accuracy: 0.7073 - val_loss: 2.0268 - val_accuracy: 0.5631
# Epoch 46/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.5761 - accuracy: 0.7075 - val_loss: 2.0136 - val_accuracy: 0.5595
# Epoch 47/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.5413 - accuracy: 0.7150 - val_loss: 1.9858 - val_accuracy: 0.5614
# Epoch 48/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.5009 - accuracy: 0.7187 - val_loss: 1.9760 - val_accuracy: 0.5582
# Epoch 49/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.4793 - accuracy: 0.7170 - val_loss: 1.9749 - val_accuracy: 0.5588
# Epoch 50/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.4446 - accuracy: 0.7242 - val_loss: 1.9531 - val_accuracy: 0.5627
# Epoch 51/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.4142 - accuracy: 0.7276 - val_loss: 1.9097 - val_accuracy: 0.5689
# Epoch 52/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.3833 - accuracy: 0.7321 - val_loss: 1.8926 - val_accuracy: 0.5660
# Epoch 53/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.3523 - accuracy: 0.7377 - val_loss: 1.8878 - val_accuracy: 0.5694
# Epoch 54/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.3256 - accuracy: 0.7429 - val_loss: 1.8721 - val_accuracy: 0.5691
# Epoch 55/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.3069 - accuracy: 0.7428 - val_loss: 1.8672 - val_accuracy: 0.5717
# Epoch 56/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.2810 - accuracy: 0.7470 - val_loss: 1.8523 - val_accuracy: 0.5661
# Epoch 57/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.2549 - accuracy: 0.7517 - val_loss: 1.8919 - val_accuracy: 0.5584
# Epoch 58/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.2275 - accuracy: 0.7556 - val_loss: 1.8576 - val_accuracy: 0.5658
# Epoch 59/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.2222 - accuracy: 0.7548 - val_loss: 1.8446 - val_accuracy: 0.5668
# Epoch 60/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.1836 - accuracy: 0.7635 - val_loss: 1.8188 - val_accuracy: 0.5728
# Epoch 61/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.1508 - accuracy: 0.7719 - val_loss: 1.8492 - val_accuracy: 0.5616
# Epoch 62/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.1480 - accuracy: 0.7715 - val_loss: 1.8285 - val_accuracy: 0.5665
# Epoch 63/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.1300 - accuracy: 0.7722 - val_loss: 1.8254 - val_accuracy: 0.5618
# Epoch 64/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.1187 - accuracy: 0.7735 - val_loss: 1.8260 - val_accuracy: 0.5616
# Epoch 65/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.0949 - accuracy: 0.7794 - val_loss: 1.8121 - val_accuracy: 0.5664
# Epoch 66/80
# 50000/50000 [==============================] - 1s 24us/step - loss: 1.0845 - accuracy: 0.7809 - val_loss: 1.8208 - val_accuracy: 0.5646
# Epoch 67/80
# 50000/50000 [==============================] - 1s 27us/step - loss: 1.0554 - accuracy: 0.7885 - val_loss: 1.8309 - val_accuracy: 0.5638
# Epoch 68/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.0453 - accuracy: 0.7887 - val_loss: 1.8159 - val_accuracy: 0.5663
# Epoch 69/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.0322 - accuracy: 0.7908 - val_loss: 1.8156 - val_accuracy: 0.5650
# Epoch 70/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 1.0189 - accuracy: 0.7951 - val_loss: 1.8290 - val_accuracy: 0.5658
# Epoch 71/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 1.0102 - accuracy: 0.7952 - val_loss: 1.8045 - val_accuracy: 0.5664
# Epoch 72/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 0.9876 - accuracy: 0.8006 - val_loss: 1.7916 - val_accuracy: 0.5673
# Epoch 73/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.9677 - accuracy: 0.8053 - val_loss: 1.8050 - val_accuracy: 0.5601
# Epoch 74/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 0.9637 - accuracy: 0.8073 - val_loss: 1.8207 - val_accuracy: 0.5627
# Epoch 75/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 0.9564 - accuracy: 0.8089 - val_loss: 1.8143 - val_accuracy: 0.5663
# Epoch 76/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.9486 - accuracy: 0.8073 - val_loss: 1.8071 - val_accuracy: 0.5608
# Epoch 77/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 0.9329 - accuracy: 0.8127 - val_loss: 1.8464 - val_accuracy: 0.5609
# Epoch 78/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 0.9366 - accuracy: 0.8119 - val_loss: 1.8140 - val_accuracy: 0.5616
# Epoch 79/80
# 50000/50000 [==============================] - 1s 25us/step - loss: 0.9100 - accuracy: 0.8183 - val_loss: 1.8259 - val_accuracy: 0.5612
# Epoch 80/80
# 50000/50000 [==============================] - 1s 26us/step - loss: 0.9032 - accuracy: 0.8181 - val_loss: 1.8363 - val_accuracy: 0.5667
# 10000/10000 [==============================] - 1s 70us/step

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
"""Code Here
將結果繪出
"""
plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.hlines(y=loss_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.hlines(y=acc_loadback, xmin=0, xmax=len(train_loss), colors='r', linestyles='--')
plt.legend()
plt.title("Accuracy")
plt.show()
