# %%
from keras import backend as K
from keras.models import Model
from keras.layers import Flatten, Dense, Dropout
from keras.applications.resnet50 import ResNet50
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
import numpy as np
import pandas as pd
import os
# Out:
# Using TensorFlow backend.

# %%
# 資料路徑
DATASET_PATH  = './image_data'

# 影像大小
IMAGE_SIZE = (224, 224)

# 影像類別數
NUM_CLASSES = 5

# 若 GPU 記憶體不足，可調降 batch size 或凍結更多層網路
BATCH_SIZE = 16

# Epoch 數
NUM_EPOCHS = 200

# 模型輸出儲存的檔案
WEIGHTS_FINAL = 'model-resnet50-final.h5'
WEIGHTS_LAST = 'model-resnet50-last.h5'

# 是否載入已訓練模型
load_mode = True

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=30,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   channel_shift_range=10,
                                   horizontal_flip=True,
                                   fill_mode='nearest',
                                   validation_split=0.1)  # set validation split


train_batches = train_datagen.flow_from_directory(DATASET_PATH + '/train',
                                                  target_size=IMAGE_SIZE,
                                                  interpolation='bicubic',
                                                  class_mode='categorical',
                                                  batch_size=BATCH_SIZE,
                                                  shuffle=True, 
                                                  subset='training') # set as training data

valid_batches = train_datagen.flow_from_directory(DATASET_PATH + '/train',
                                                  target_size=IMAGE_SIZE,
                                                  interpolation='bicubic',
                                                  class_mode='categorical',
                                                  batch_size=BATCH_SIZE,
                                                  shuffle=True,
                                                  subset='validation') # set as validation data

test_datagen = ImageDataGenerator(rescale=1./255)
test_batches = test_datagen.flow_from_directory(  DATASET_PATH + '/test',
                                                  target_size=IMAGE_SIZE,
                                                  interpolation='bicubic',
                                                  class_mode=None,
                                                  shuffle=False,
                                                  batch_size=1,)

# 輸出各類別的索引值
print('----- train_batch ----- {} samples'.format(train_batches.samples))
for cls, idx in train_batches.class_indices.items():
    print('Class #{} = {}'.format(idx, cls))

# 輸出各類別的索引值
print('----- valid_batch ----- {} samples'.format(valid_batches.samples))
for cls, idx in valid_batches.class_indices.items():
    print('Class #{} = {}'.format(idx, cls))

# 輸出各類別的索引值
print('----- test_batch ----- {} samples'.format(test_batches.samples))
for cls, idx in test_batches.class_indices.items():
    print('Class #{} = {}'.format(idx, cls))
# Out:
# Found 2543 images belonging to 5 classes.
# Found 280 images belonging to 5 classes.
# Found 2000 images belonging to 1 classes.
# ----- train_batch ----- 2543 samples
# Class #0 = daisy
# Class #1 = dandelion
# Class #2 = rose
# Class #3 = sunflower
# Class #4 = tulip
# ----- valid_batch ----- 280 samples
# Class #0 = daisy
# Class #1 = dandelion
# Class #2 = rose
# Class #3 = sunflower
# Class #4 = tulip
# ----- test_batch ----- 2000 samples
# Class #0 = flower

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule
    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.
    # Arguments
        epoch (int): The number of epochs
    # Returns
        lr (float32): learning rate
    """
    global load_mode
    
    if load_mode:
        lr = 1e-4
    else:
        lr = 1e-3
    if epoch > 150:
        lr *= 0.5e-3
    elif epoch > 120:
        lr *= 1e-3
    elif epoch > 90:
        lr *= 1e-2
    elif epoch > 50:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
# 准备模型保存路径。
save_dir = os.path.join(DATASET_PATH, 'saved_models')
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, WEIGHTS_FINAL)

# 准备保存模型和学习速率调整的回调。
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_accuracy',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
# 以訓練好的 ResNet50 為基礎來建立模型，
if load_mode :
    from keras.models import load_model
    # identical to the best one
    net_final = load_model(os.path.join(save_dir, WEIGHTS_FINAL))
else:
    # 捨棄 ResNet50 頂層的 fully connected layers
    net = ResNet50(include_top=True, weights='imagenet', input_tensor=None,
                input_shape=(IMAGE_SIZE[0],IMAGE_SIZE[1],3))

    # remove classification layer
    net.layers.pop()
    net = Model(inputs=net.input, outputs=net.layers[-1].output)

    # # 設定凍結與要進行訓練的網路層
    # for layer in net.layers:
    #     layer.trainable = False

    x = net.output
    #x = Flatten()(x)

    # 增加 DropOut layer
    x = Dropout(0.5)(x)

    # 增加 Dense layer，以 softmax 產生個類別的機率值
    output_layer = Dense(NUM_CLASSES, activation='softmax', name='softmax')(x)

    net_final = Model(inputs=net.input, outputs=output_layer)


# 使用 Adam optimizer，以較低的 learning rate 進行 fine-tuning
net_final.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])

# 輸出整個網路結構
print(net_final.summary())
# Out:
#
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 14, 14, 256)  0           bn4a_branch2a[0][0]
# __________________________________________________________________________________________________
# res4a_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_23[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 14, 14, 256)  0           bn4a_branch2b[0][0]
# __________________________________________________________________________________________________
# res4a_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_24[0][0]
# __________________________________________________________________________________________________
# res4a_branch1 (Conv2D)          (None, 14, 14, 1024) 525312      activation_22[0][0]
# __________________________________________________________________________________________________
# bn4a_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn4a_branch1 (BatchNormalizatio (None, 14, 14, 1024) 4096        res4a_branch1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 1024) 0           bn4a_branch2c[0][0]
#                                                                  bn4a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 14, 14, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# res4b_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_25[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 14, 14, 256)  0           bn4b_branch2a[0][0]
# __________________________________________________________________________________________________
# res4b_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_26[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 14, 14, 256)  0           bn4b_branch2b[0][0]
# __________________________________________________________________________________________________
# res4b_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_27[0][0]
# __________________________________________________________________________________________________
# bn4b_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 1024) 0           bn4b_branch2c[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 14, 14, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# res4c_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_28[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 14, 14, 256)  0           bn4c_branch2a[0][0]
# __________________________________________________________________________________________________
# res4c_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_29[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 14, 14, 256)  0           bn4c_branch2b[0][0]
# __________________________________________________________________________________________________
# res4c_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_30[0][0]
# __________________________________________________________________________________________________
# bn4c_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 1024) 0           bn4c_branch2c[0][0]
#                                                                  activation_28[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 14, 14, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# res4d_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_31[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 14, 14, 256)  0           bn4d_branch2a[0][0]
# __________________________________________________________________________________________________
# res4d_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_32[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4d_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 14, 14, 256)  0           bn4d_branch2b[0][0]
# __________________________________________________________________________________________________
# res4d_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_33[0][0]
# __________________________________________________________________________________________________
# bn4d_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4d_branch2c[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 14, 14, 1024) 0           bn4d_branch2c[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 14, 14, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# res4e_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_34[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 14, 14, 256)  0           bn4e_branch2a[0][0]
# __________________________________________________________________________________________________
# res4e_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_35[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4e_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 14, 14, 256)  0           bn4e_branch2b[0][0]
# __________________________________________________________________________________________________
# res4e_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_36[0][0]
# __________________________________________________________________________________________________
# bn4e_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4e_branch2c[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 1024) 0           bn4e_branch2c[0][0]
#                                                                  activation_34[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 14, 14, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# res4f_branch2a (Conv2D)         (None, 14, 14, 256)  262400      activation_37[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2a (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 14, 14, 256)  0           bn4f_branch2a[0][0]
# __________________________________________________________________________________________________
# res4f_branch2b (Conv2D)         (None, 14, 14, 256)  590080      activation_38[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2b (BatchNormalizati (None, 14, 14, 256)  1024        res4f_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 14, 14, 256)  0           bn4f_branch2b[0][0]
# __________________________________________________________________________________________________
# res4f_branch2c (Conv2D)         (None, 14, 14, 1024) 263168      activation_39[0][0]
# __________________________________________________________________________________________________
# bn4f_branch2c (BatchNormalizati (None, 14, 14, 1024) 4096        res4f_branch2c[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 14, 14, 1024) 0           bn4f_branch2c[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 14, 14, 1024) 0           add_13[0][0]
# __________________________________________________________________________________________________
# res5a_branch2a (Conv2D)         (None, 7, 7, 512)    524800      activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 7, 7, 512)    0           bn5a_branch2a[0][0]
# __________________________________________________________________________________________________
# res5a_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_41[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5a_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 7, 7, 512)    0           bn5a_branch2b[0][0]
# __________________________________________________________________________________________________
# res5a_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_42[0][0]
# __________________________________________________________________________________________________
# res5a_branch1 (Conv2D)          (None, 7, 7, 2048)   2099200     activation_40[0][0]
# __________________________________________________________________________________________________
# bn5a_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5a_branch2c[0][0]
# __________________________________________________________________________________________________
# bn5a_branch1 (BatchNormalizatio (None, 7, 7, 2048)   8192        res5a_branch1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 7, 7, 2048)   0           bn5a_branch2c[0][0]
#                                                                  bn5a_branch1[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 7, 7, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# res5b_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_43[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 7, 7, 512)    0           bn5b_branch2a[0][0]
# __________________________________________________________________________________________________
# res5b_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_44[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5b_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 7, 7, 512)    0           bn5b_branch2b[0][0]
# __________________________________________________________________________________________________
# res5b_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_45[0][0]
# __________________________________________________________________________________________________
# bn5b_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5b_branch2c[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 2048)   0           bn5b_branch2c[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 7, 7, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# res5c_branch2a (Conv2D)         (None, 7, 7, 512)    1049088     activation_46[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2a (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2a[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 7, 7, 512)    0           bn5c_branch2a[0][0]
# __________________________________________________________________________________________________
# res5c_branch2b (Conv2D)         (None, 7, 7, 512)    2359808     activation_47[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2b (BatchNormalizati (None, 7, 7, 512)    2048        res5c_branch2b[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 7, 7, 512)    0           bn5c_branch2b[0][0]
# __________________________________________________________________________________________________
# res5c_branch2c (Conv2D)         (None, 7, 7, 2048)   1050624     activation_48[0][0]
# __________________________________________________________________________________________________
# bn5c_branch2c (BatchNormalizati (None, 7, 7, 2048)   8192        res5c_branch2c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 7, 7, 2048)   0           bn5c_branch2c[0][0]
#                                                                  activation_46[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 7, 7, 2048)   0           add_16[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling2 (None, 2048)         0           activation_49[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 2048)         0           avg_pool[0][0]
# __________________________________________________________________________________________________
# softmax (Dense)                 (None, 5)            10245       dropout_1[0][0]
# ==================================================================================================
# Total params: 23,597,957
# Trainable params: 23,544,837
# Non-trainable params: 53,120
# __________________________________________________________________________________________________
# None

# %%
# 訓練模型
net_final.fit_generator(train_batches,
                        steps_per_epoch = train_batches.samples // BATCH_SIZE,
                        validation_data = valid_batches,
                        validation_steps = valid_batches.samples // BATCH_SIZE,
                        epochs = NUM_EPOCHS,
                        verbose=1,
                        callbacks=callbacks)

# 儲存訓練好的模型
modelpath = os.path.join(save_dir, WEIGHTS_LAST)
net_final.save(modelpath)
# Out:
#  improve from 0.96212
# Epoch 119/200
# Learning rate:  1.0000000000000002e-06
# 158/158 [==============================] - 41s 258ms/step - loss: 0.0074 - accuracy: 0.9968 - val_loss: 1.1067e-04 - val_accuracy: 0.9280
#
# Epoch 00119: val_accuracy did not improve from 0.96212
# Epoch 120/200
# Learning rate:  1.0000000000000002e-06
# 158/158 [==============================] - 40s 254ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 0.2132 - val_accuracy: 0.9242
#
# Epoch 00120: val_accuracy did not improve from 0.96212
# Epoch 121/200
# Learning rate:  1.0000000000000002e-06
# 158/158 [==============================] - 40s 253ms/step - loss: 0.0082 - accuracy: 0.9960 - val_loss: 1.5215e-04 - val_accuracy: 0.9356
#
# Epoch 00121: val_accuracy did not improve from 0.96212
# Epoch 122/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 40s 252ms/step - loss: 0.0081 - accuracy: 0.9972 - val_loss: 0.7906 - val_accuracy: 0.9167
#
# Epoch 00122: val_accuracy did not improve from 0.96212
# Epoch 123/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 40s 252ms/step - loss: 0.0077 - accuracy: 0.9988 - val_loss: 0.1109 - val_accuracy: 0.9356
#
# Epoch 00123: val_accuracy did not improve from 0.96212
# Epoch 124/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 40s 251ms/step - loss: 0.0099 - accuracy: 0.9968 - val_loss: 0.4768 - val_accuracy: 0.9318
#
# Epoch 00124: val_accuracy did not improve from 0.96212
# Epoch 125/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 40s 251ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0063 - val_accuracy: 0.9280
#
# Epoch 00125: val_accuracy did not improve from 0.96212
# Epoch 126/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 39s 250ms/step - loss: 0.0132 - accuracy: 0.9956 - val_loss: 1.1174e-04 - val_accuracy: 0.9053
#
# Epoch 00126: val_accuracy did not improve from 0.96212
# Epoch 127/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 40s 251ms/step - loss: 0.0100 - accuracy: 0.9972 - val_loss: 0.3065 - val_accuracy: 0.9118
#
# Epoch 00127: val_accuracy did not improve from 0.96212
# Epoch 128/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 41s 262ms/step - loss: 0.0087 - accuracy: 0.9976 - val_loss: 1.0336 - val_accuracy: 0.9167
#
# Epoch 00128: val_accuracy did not improve from 0.96212
# Epoch 129/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 41s 260ms/step - loss: 0.0050 - accuracy: 0.9988 - val_loss: 0.3486 - val_accuracy: 0.9242
#
# Epoch 00129: val_accuracy did not improve from 0.96212
# Epoch 130/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 41s 259ms/step - loss: 0.0086 - accuracy: 0.9964 - val_loss: 0.0432 - val_accuracy: 0.9318
#
# Epoch 00130: val_accuracy did not improve from 0.96212
# Epoch 131/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 41s 259ms/step - loss: 0.0062 - accuracy: 0.9976 - val_loss: 0.3349 - val_accuracy: 0.9091
#
# Epoch 00131: val_accuracy did not improve from 0.96212
# Epoch 132/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 41s 258ms/step - loss: 0.0094 - accuracy: 0.9968 - val_loss: 1.0684 - val_accuracy: 0.9205
#
# Epoch 00132: val_accuracy did not improve from 0.96212
# Epoch 133/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 41s 257ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 0.0017 - val_accuracy: 0.9318
#
# Epoch 00133: val_accuracy did not improve from 0.96212
# Epoch 134/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 40s 256ms/step - loss: 0.0072 - accuracy: 0.9980 - val_loss: 5.3434e-04 - val_accuracy: 0.9205
#
# Epoch 00134: val_accuracy did not improve from 0.96212
# Epoch 135/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 40s 256ms/step - loss: 0.0073 - accuracy: 0.9964 - val_loss: 0.9058 - val_accuracy: 0.9432
#
# Epoch 00135: val_accuracy did not improve from 0.96212
# Epoch 136/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 40s 256ms/step - loss: 0.0122 - accuracy: 0.9964 - val_loss: 0.0691 - val_accuracy: 0.9167
#
# Epoch 00136: val_accuracy did not improve from 0.96212
# Epoch 137/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 40s 255ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.5190 - val_accuracy: 0.9394
#
# Epoch 00137: val_accuracy did not improve from 0.96212
# Epoch 138/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 40s 254ms/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 1.4700e-04 - val_accuracy: 0.9318
#
# Epoch 00138: val_accuracy did not improve from 0.96212
# Epoch 139/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 43s 272ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.0043 - val_accuracy: 0.9129
#
# Epoch 00139: val_accuracy did not improve from 0.96212
# Epoch 140/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 43s 271ms/step - loss: 0.0099 - accuracy: 0.9964 - val_loss: 0.8093 - val_accuracy: 0.9015
#
# Epoch 00140: val_accuracy did not improve from 0.96212
# Epoch 141/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 43s 270ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 0.7432 - val_accuracy: 0.9205
#
# Epoch 00141: val_accuracy did not improve from 0.96212
# Epoch 142/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 43s 269ms/step - loss: 0.0080 - accuracy: 0.9976 - val_loss: 0.0225 - val_accuracy: 0.9356
#
# Epoch 00142: val_accuracy did not improve from 0.96212
# Epoch 143/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 42s 268ms/step - loss: 0.0077 - accuracy: 0.9976 - val_loss: 0.0436 - val_accuracy: 0.9129
#
# Epoch 00143: val_accuracy did not improve from 0.96212
# Epoch 144/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 42s 268ms/step - loss: 0.0091 - accuracy: 0.9964 - val_loss: 9.8866e-05 - val_accuracy: 0.9318
#
# Epoch 00144: val_accuracy did not improve from 0.96212
# Epoch 145/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 42s 268ms/step - loss: 0.0093 - accuracy: 0.9968 - val_loss: 0.0456 - val_accuracy: 0.9154
#
# Epoch 00145: val_accuracy did not improve from 0.96212
# Epoch 146/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 44s 280ms/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.2060 - val_accuracy: 0.9432
#
# Epoch 00146: val_accuracy did not improve from 0.96212
# Epoch 147/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 44s 279ms/step - loss: 0.0082 - accuracy: 0.9984 - val_loss: 0.6552 - val_accuracy: 0.9242
#
# Epoch 00147: val_accuracy did not improve from 0.96212
# Epoch 148/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 44s 278ms/step - loss: 0.0129 - accuracy: 0.9976 - val_loss: 1.2415 - val_accuracy: 0.9318
#
# Epoch 00148: val_accuracy did not improve from 0.96212
# Epoch 149/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 44s 278ms/step - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.9576 - val_accuracy: 0.9091
#
# Epoch 00149: val_accuracy did not improve from 0.96212
# Epoch 150/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 44s 277ms/step - loss: 0.0132 - accuracy: 0.9956 - val_loss: 3.2357e-05 - val_accuracy: 0.9545
#
# Epoch 00150: val_accuracy did not improve from 0.96212
# Epoch 151/200
# Learning rate:  1.0000000000000001e-07
# 158/158 [==============================] - 44s 276ms/step - loss: 0.0066 - accuracy: 0.9976 - val_loss: 4.9032e-05 - val_accuracy: 0.8977
#
# Epoch 00151: val_accuracy did not improve from 0.96212
# Epoch 152/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 44s 276ms/step - loss: 0.0079 - accuracy: 0.9980 - val_loss: 0.1178 - val_accuracy: 0.9242
#
# Epoch 00152: val_accuracy did not improve from 0.96212
# Epoch 153/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 275ms/step - loss: 0.0108 - accuracy: 0.9956 - val_loss: 7.5473e-05 - val_accuracy: 0.9318
#
# Epoch 00153: val_accuracy did not improve from 0.96212
# Epoch 154/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 275ms/step - loss: 0.0055 - accuracy: 0.9980 - val_loss: 0.2620 - val_accuracy: 0.9280
#
# Epoch 00154: val_accuracy did not improve from 0.96212
# Epoch 155/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 273ms/step - loss: 0.0080 - accuracy: 0.9968 - val_loss: 1.4156 - val_accuracy: 0.9129
#
# Epoch 00155: val_accuracy did not improve from 0.96212
# Epoch 156/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 272ms/step - loss: 0.0045 - accuracy: 0.9988 - val_loss: 0.5212 - val_accuracy: 0.9432
#
# Epoch 00156: val_accuracy did not improve from 0.96212
# Epoch 157/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 272ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.0017 - val_accuracy: 0.9394
#
# Epoch 00157: val_accuracy did not improve from 0.96212
# Epoch 158/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 271ms/step - loss: 0.0073 - accuracy: 0.9980 - val_loss: 0.9723 - val_accuracy: 0.9242
#
# Epoch 00158: val_accuracy did not improve from 0.96212
# Epoch 159/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 270ms/step - loss: 0.0101 - accuracy: 0.9960 - val_loss: 0.0635 - val_accuracy: 0.9356
#
# Epoch 00159: val_accuracy did not improve from 0.96212
# Epoch 160/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 269ms/step - loss: 0.0100 - accuracy: 0.9964 - val_loss: 0.0042 - val_accuracy: 0.9129
#
# Epoch 00160: val_accuracy did not improve from 0.96212
# Epoch 161/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 42s 268ms/step - loss: 0.0044 - accuracy: 0.9980 - val_loss: 0.0103 - val_accuracy: 0.9280
#
# Epoch 00161: val_accuracy did not improve from 0.96212
# Epoch 162/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 42s 267ms/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.1216 - val_accuracy: 0.9242
#
# Epoch 00162: val_accuracy did not improve from 0.96212
# Epoch 163/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 42s 268ms/step - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.6000 - val_accuracy: 0.9228
#
# Epoch 00163: val_accuracy did not improve from 0.96212
# Epoch 164/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 44s 280ms/step - loss: 0.0051 - accuracy: 0.9980 - val_loss: 0.3256 - val_accuracy: 0.9205
#
# Epoch 00164: val_accuracy did not improve from 0.96212
# Epoch 165/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 44s 278ms/step - loss: 0.0090 - accuracy: 0.9960 - val_loss: 0.8823 - val_accuracy: 0.9129
#
# Epoch 00165: val_accuracy did not improve from 0.96212
# Epoch 166/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 44s 278ms/step - loss: 0.0074 - accuracy: 0.9980 - val_loss: 3.2926e-04 - val_accuracy: 0.9129
#
# Epoch 00166: val_accuracy did not improve from 0.96212
# Epoch 167/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 44s 278ms/step - loss: 0.0088 - accuracy: 0.9968 - val_loss: 0.4693 - val_accuracy: 0.9167
#
# Epoch 00167: val_accuracy did not improve from 0.96212
# Epoch 168/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 44s 276ms/step - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.1510 - val_accuracy: 0.9167
#
# Epoch 00168: val_accuracy did not improve from 0.96212
# Epoch 169/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 44s 276ms/step - loss: 0.0045 - accuracy: 0.9988 - val_loss: 0.0148 - val_accuracy: 0.9280
#
# Epoch 00169: val_accuracy did not improve from 0.96212
# Epoch 170/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 44s 275ms/step - loss: 0.0054 - accuracy: 0.9988 - val_loss: 3.0834e-04 - val_accuracy: 0.9356
#
# Epoch 00170: val_accuracy did not improve from 0.96212
# Epoch 171/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 274ms/step - loss: 0.0076 - accuracy: 0.9972 - val_loss: 0.0053 - val_accuracy: 0.9129
#
# Epoch 00171: val_accuracy did not improve from 0.96212
# Epoch 172/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 274ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 1.3449e-04 - val_accuracy: 0.9242
#
# Epoch 00172: val_accuracy did not improve from 0.96212
# Epoch 173/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 273ms/step - loss: 0.0069 - accuracy: 0.9972 - val_loss: 0.0171 - val_accuracy: 0.9318
#
# Epoch 00173: val_accuracy did not improve from 0.96212
# Epoch 174/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 272ms/step - loss: 0.0111 - accuracy: 0.9960 - val_loss: 0.9004 - val_accuracy: 0.8902
#
# Epoch 00174: val_accuracy did not improve from 0.96212
# Epoch 175/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 272ms/step - loss: 0.0100 - accuracy: 0.9968 - val_loss: 0.2752 - val_accuracy: 0.9356
#
# Epoch 00175: val_accuracy did not improve from 0.96212
# Epoch 176/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 271ms/step - loss: 0.0099 - accuracy: 0.9976 - val_loss: 0.7531 - val_accuracy: 0.9318
#
# Epoch 00176: val_accuracy did not improve from 0.96212
# Epoch 177/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 270ms/step - loss: 0.0083 - accuracy: 0.9960 - val_loss: 0.0879 - val_accuracy: 0.9318
#
# Epoch 00177: val_accuracy did not improve from 0.96212
# Epoch 178/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 269ms/step - loss: 0.0066 - accuracy: 0.9988 - val_loss: 0.3017 - val_accuracy: 0.9318
#
# Epoch 00178: val_accuracy did not improve from 0.96212
# Epoch 179/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 42s 268ms/step - loss: 0.0075 - accuracy: 0.9972 - val_loss: 5.6052e-04 - val_accuracy: 0.9242
#
# Epoch 00179: val_accuracy did not improve from 0.96212
# Epoch 180/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 42s 268ms/step - loss: 0.0071 - accuracy: 0.9984 - val_loss: 0.5017 - val_accuracy: 0.9242
#
# Epoch 00180: val_accuracy did not improve from 0.96212
# Epoch 181/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 42s 268ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.0016 - val_accuracy: 0.9338
#
# Epoch 00181: val_accuracy did not improve from 0.96212
# Epoch 182/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 45s 284ms/step - loss: 0.0043 - accuracy: 0.9988 - val_loss: 0.7167 - val_accuracy: 0.9432
#
# Epoch 00182: val_accuracy did not improve from 0.96212
# Epoch 183/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 44s 280ms/step - loss: 0.0092 - accuracy: 0.9968 - val_loss: 0.1743 - val_accuracy: 0.9129
#
# Epoch 00183: val_accuracy did not improve from 0.96212
# Epoch 184/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 44s 279ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.3741 - val_accuracy: 0.9280
#
# Epoch 00184: val_accuracy did not improve from 0.96212
# Epoch 185/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 44s 277ms/step - loss: 0.0071 - accuracy: 0.9980 - val_loss: 0.1636 - val_accuracy: 0.9167
#
# Epoch 00185: val_accuracy did not improve from 0.96212
# Epoch 186/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 44s 277ms/step - loss: 0.0059 - accuracy: 0.9992 - val_loss: 0.1847 - val_accuracy: 0.9129
#
# Epoch 00186: val_accuracy did not improve from 0.96212
# Epoch 187/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 44s 276ms/step - loss: 0.0073 - accuracy: 0.9980 - val_loss: 1.3637 - val_accuracy: 0.9280
#
# Epoch 00187: val_accuracy did not improve from 0.96212
# Epoch 188/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 275ms/step - loss: 0.0047 - accuracy: 0.9992 - val_loss: 0.0015 - val_accuracy: 0.9280
#
# Epoch 00188: val_accuracy did not improve from 0.96212
# Epoch 189/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 275ms/step - loss: 0.0137 - accuracy: 0.9956 - val_loss: 1.0546 - val_accuracy: 0.9470
#
# Epoch 00189: val_accuracy did not improve from 0.96212
# Epoch 190/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 274ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 0.4532 - val_accuracy: 0.9167
#
# Epoch 00190: val_accuracy did not improve from 0.96212
# Epoch 191/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 273ms/step - loss: 0.0061 - accuracy: 0.9980 - val_loss: 0.0068 - val_accuracy: 0.9280
#
# Epoch 00191: val_accuracy did not improve from 0.96212
# Epoch 192/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 272ms/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.1723 - val_accuracy: 0.9242
#
# Epoch 00192: val_accuracy did not improve from 0.96212
# Epoch 193/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 271ms/step - loss: 0.0069 - accuracy: 0.9980 - val_loss: 0.0032 - val_accuracy: 0.9129
#
# Epoch 00193: val_accuracy did not improve from 0.96212
# Epoch 194/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 270ms/step - loss: 0.0092 - accuracy: 0.9976 - val_loss: 0.0584 - val_accuracy: 0.9318
#
# Epoch 00194: val_accuracy did not improve from 0.96212
# Epoch 195/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 43s 270ms/step - loss: 0.0113 - accuracy: 0.9972 - val_loss: 0.0643 - val_accuracy: 0.9167
#
# Epoch 00195: val_accuracy did not improve from 0.96212
# Epoch 196/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 42s 269ms/step - loss: 0.0076 - accuracy: 0.9984 - val_loss: 0.5507 - val_accuracy: 0.9242
#
# Epoch 00196: val_accuracy did not improve from 0.96212
# Epoch 197/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 42s 268ms/step - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.1172 - val_accuracy: 0.9167
#
# Epoch 00197: val_accuracy did not improve from 0.96212
# Epoch 198/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 42s 266ms/step - loss: 0.0078 - accuracy: 0.9980 - val_loss: 0.6885 - val_accuracy: 0.9167
#
# Epoch 00198: val_accuracy did not improve from 0.96212
# Epoch 199/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 42s 268ms/step - loss: 0.0063 - accuracy: 0.9984 - val_loss: 1.1982 - val_accuracy: 0.9191
#
# Epoch 00199: val_accuracy did not improve from 0.96212
# Epoch 200/200
# Learning rate:  5.0000000000000004e-08
# 158/158 [==============================] - 44s 280ms/step - loss: 0.0108 - accuracy: 0.9972 - val_loss: 0.1588 - val_accuracy: 0.9205
#
# Epoch 00200: val_accuracy did not improve from 0.96212

# %%
from keras.models import load_model

# identical to the best one
net_final = load_model(os.path.join(save_dir, WEIGHTS_FINAL))

test_batches.reset()
pred = net_final.predict_generator(test_batches, verbose=1)
# Out:
# 2000/2000 [==============================] - 28s 14ms/step

# %%
predicted_class_indices = np.argmax(pred, axis=1)
labels = (train_batches.class_indices)
label = dict((v,k) for k,v in labels.items())
predictions = [label[i] for i in predicted_class_indices]
# 修正檔名
filenames = test_batches.filenames
id = [name.replace('.jpg','').replace('all/','') for name in filenames]
# 輸出 csv 檔 id, flower_class
df = pd.DataFrame({"id":id, "flower_class":predicted_class_indices})
df.to_csv(DATASET_PATH + '/submission.csv', index=False)

# %%
net_final.evaluate_generator(valid_batches, verbose=1)
# Out:
# 18/18 [==============================] - 3s 179ms/step
# [2.604016065597534, 0.9285714030265808]
